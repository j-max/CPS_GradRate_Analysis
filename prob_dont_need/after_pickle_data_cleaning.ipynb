# %%
import pandas as pd
import pickle

# %%
with open('data/pickles/hs_data_16-18.pickle','rb') as read_file:
    df = pickle.load(read_file)

# %%
hhinc_2016 = pd.read_csv('data/meanHHincome_2016.csv', header = None)

# %%
hhinc_2017 = pd.read_csv('data/meanHHincome_2017.csv', header = None)

# %%
print(hhinc_2017)
# Out:
#         0        1
# 0   60602  172,492
# 1   60605  157,763
# 2   60607  120,419
# 3   60608   57,770
# 4   60609   47,139
# 5   60610  132,877
# 6   60612   60,654
# 7   60613  113,058
# 8   60614  149,897
# 9   60615   67,727
# 10  60616   66,098
# 11  60617   51,429
# 12  60618   97,946
# 13  60619   46,846
# 14  60620   47,131
# 15  60621   32,722
# 16  60622  119,502
# 17  60623   41,680
# 18  60624   36,426
# 19  60625   86,237
# 20  60626   56,683
# 21  60627        0
# 22  60628   52,448
# 23  60629   54,685
# 24  60631  105,355
# 25  60632   55,174
# 26  60634   77,020
# 27  60636   40,691
# 28  60637   55,880
# 29  60638   79,245
# 30  60639   54,396
# 31  60640   75,075
# 32  60641   73,909
# 33  60642  114,612
# 34  60643   83,368
# 35  60644   41,174
# 36  60649   43,822
# 37  60651   49,663
# 38  60652   76,125
# 39  60653   51,883
# 40  60655  105,761
# 41  60659   68,047
# 42  60660   66,167

# %%
print(list(df))
# Out:
# ['ADA_Accessible', 'Address', 'Administrator', 'Administrator_Title', 'After_School_Hours', 'Attendance_Boundaries', 'Average_ACT_School', 'Bilingual_Services', 'CPS_School_Profile', 'City', 'Classification_Description', 'Classroom_Languages', 'Closed_For_Enrollment_Date', 'College_Enrollment_Rate_Mean', 'College_Enrollment_Rate_School', 'Demographic_Description', 'Dress_Code', 'Earliest_Drop_Off_Time', 'Facebook', 'Fax', 'Fifth_Contact_Name', 'Fifth_Contact_Title', 'Finance_ID', 'Fourth_Contact_Name', 'Fourth_Contact_Title', 'Freshman_Start_End_Time', 'Grades_Offered', 'Grades_Offered_All', 'Graduation_Rate_Mean', 'Graduation_Rate_School', 'Hard_Of_Hearing', 'Is_Elementary_School', 'Is_GoCPS_Elementary', 'Is_GoCPS_High_School', 'Is_GoCPS_Participant', 'Is_GoCPS_PreK', 'Is_High_School', 'Is_Middle_School', 'Is_Pre_School', 'Kindergarten_School_Day', 'Legacy_Unit_ID', 'Location', 'Long_Name', 'Mean_ACT', 'Network', 'Open_For_Enrollment_Date', 'Overall_Rating', 'Phone', 'Pinterest', 'P
# ...

# %%
print(df[['School_ID', 'School_Year']])
# Out:
#      School_ID            School_Year
# 0       609764  School Year 2016-2017
# 1       609764  School Year 2017-2018
# 2       400054  School Year 2016-2017
# 3       400054  School Year 2017-2018
# 4       609726  School Year 2016-2017
# 5       609726  School Year 2017-2018
# 6       400094  School Year 2016-2017
# 7       400094  School Year 2017-2018
# 8       609755  School Year 2016-2017
# 9       609755  School Year 2017-2018
# 10      609756  School Year 2016-2017
# 11      609756  School Year 2017-2018
# 12      610518  School Year 2016-2017
# 13      610518  School Year 2017-2018
# 14      400077  School Year 2016-2017
# 15      400077  School Year 2017-2018
# 16      400056  School Year 2016-2017
# 17      400056  School Year 2017-2018
# 18      610394  School Year 2016-2017
# 19      610394  School Year 2017-2018
# 20      400058  School Year 2016-2017
# 21      400058  School Year 2017-2018
# 22      609692  School Year 2016-2017
# 23      609692  School Year 2017-2018
# ...

# %%
df_2016 = df[df['School_Year'] == 'School Year 2016-2017']

# %%
df_2016.head()
# Out:
#          ADA_Accessible             Address           Administrator  \
# 0  Generally accessible    1450 W CERMAK RD        Juan Carlos Ocon
# 2  Generally accessible  4131 W CORTLAND ST        Ms. Carrie Spitz
# 4      Fully Accessible      250 E 111TH ST  Ms.Shannae Bea Jackson
# 6  Generally accessible  8255 S HOUSTON AVE          Tawanna Patton
# 8  Generally accessible     211 S LAFLIN ST     Joyce Dorsey Kenner
#
#   Administrator_Title After_School_Hours Attendance_Boundaries  \
# 0           Principal  2:40 to 8:00 P.M.                     Y
# 2            Director      4:00PM-5:30PM                     N
# 4           Principal                NaN                     N
# 6            Director                NaN                     N
# 8           Principal  3:20 PM - 6:00 PM                     N
#
#    Average_ACT_School Bilingual_Services  \
# 0                16.5                  Y
# 2                21.9                  N
# 4                22.5                  N
# ...
