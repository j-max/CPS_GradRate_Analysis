# %%
# %load_ext autoreload
# %autoreload 2
import os, sys

# Set absolute path to the root folder of the directory
full_path = os.getcwd()
home_folder = 'CPS_GradRate_Analysis'
root = full_path.split(home_folder)[0] + home_folder + '/'
sys.path.append(root)

from src.maps import geo_df, chicago_shape
import matplotlib.pyplot as plt
import pandas_bokeh
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
#look into maps.py for code to create the geopandas dataframe

fig, ax = plt.subplots(figsize=(15,15))

chicago_shape.plot(ax=ax)
geo_df.plot(ax=ax, column=geo_df['Network'], markersize=geo_df['Student_Count_Total']/10, legend=True)
ax.set_title('All CPS High Schools Colored by Network\n Sized by Student Count')

plt.savefig(root+'/image_files/hs_network_map.svg')
