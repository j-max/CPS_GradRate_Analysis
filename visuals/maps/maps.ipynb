# %%
# %load_ext autoreload
# %autoreload 2
import os, sys

# Set absolute path to the root folder of the directory
full_path = os.getcwd()
home_folder = 'CPS_GradRate_Analysis'
root = full_path.split(home_folder)[0] + home_folder + '/'
sys.path.append(root)

from visuals.maps.maps import geo_df, chicago_shape
import matplotlib.pyplot as plt
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
#look into maps.py for code to create the geopandas dataframe

fig, ax = plt.subplots(figsize=(15,15))

chicago_shape.plot(ax=ax)
geo_df.plot(ax=ax, column=geo_df['Network'], legend=True)
ax.set_title('All CPS High Schools Colored by Network')
# Out:
# Text(0.5, 1.0, 'All CPS High Schools Colored by Network')
